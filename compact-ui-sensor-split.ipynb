# %%
from compact import do_it, do_it_ud

# %%
# 'JP10, MM, CA, AR, MJ, JH, CD'
# 'JP10, MM, AR, MJ, CD'
# JP05

subjects = 'JP10'
#.split(', ') # nicht hier splitten, all und all10 wird noch ersetzt und dann gesplittet

sensors_lists = ['dist pos'.split(), 'acc gyro'.split(), 'dist pos acc gyro'.split(), 'pos acc gyro'.split()]
sensors_list = sensors_lists[0]

merge_opposites = False # rename to with_opp? <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
merge_screw_lr = False
merge_screw_abc = True

fuse_slots = None
#fuse_slots = [[210, 310], [240, 340], [250, 350]]
#fuse_slots = [[210, 310], [230, 330], [235, 335]]
#fuse_slots = [[210, 310], [220, 320], [225, 325]]

# %%
do_it(subjects=subjects, sensors_list=sensors_list,
      fuse_slots=fuse_slots,
      merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc, 
      show_time=False, show_dots=False, debug=False, deep_debug=False)
# Out:
# not working with
# Analysed sensors: , dist, pos
# Differential features: , identity, diff, int1 - Statistical features: , min, max, mean
# Number of Sessions = 10
# Subjects = , JP10
# Accuracy = 87.14285714285714
# Mode =  no_opp  lr
# ---train_subjects = None
# preparation duration = 0:00:05.851401
# prediciton duration  = 0:00:04.357309
# drawing duration     = 0:00:03.524578

# %%
sensors_list = sensors_lists[1]

# %%
do_it(subjects=subjects, sensors_list=sensors_list,
      fuse_slots=fuse_slots,
      merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc, 
      show_time=False, show_dots=False, debug=False, deep_debug=False)
# Out:
# not working with
# Analysed sensors: , acc, gyro
# Differential features: , identity, diff, int1 - Statistical features: , min, max, mean
# Number of Sessions = 10
# Subjects = , JP10
# Accuracy = 88.09523809523809
# Mode =  no_opp  lr
# ---train_subjects = None
# preparation duration = 0:00:06.091755
# prediciton duration  = 0:00:04.223669
# drawing duration     = 0:00:03.266308

# %%
sensors_list = sensors_lists[2]

# %%
do_it(subjects=subjects, sensors_list=sensors_list,
      fuse_slots=fuse_slots,
      merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc, 
      show_time=False, show_dots=False, debug=False, deep_debug=False)
# Out:
# not working with
# Analysed sensors: , dist, pos, acc, gyro
# Differential features: , identity, diff, int1 - Statistical features: , min, max, mean
# Number of Sessions = 10
# Subjects = , JP10
# Accuracy = 96.19047619047619
# Mode =  no_opp  lr
# ---train_subjects = None
# preparation duration = 0:00:06.689124
# prediciton duration  = 0:00:06.459690
# drawing duration     = 0:00:03.136614
