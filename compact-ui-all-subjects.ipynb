# %%
from compact import do_it, do_it_pipe

# %%
# 'JP10, MM, CA, AR, MJ, JH, CD'
# 'JP10, MM, AR, MJ, CD'
# JP05

subjects = 'all10'
#.split(', ') # nicht hier splitten, all und all10 wird noch ersetzt und dann gesplittet

sensors_lists = ['dist pos'.split(), 'acc gyro'.split(), 'dist pos acc gyro'.split(), 'pos acc gyro'.split()]
sensors_list = sensors_lists[2]

merge_opposites = False # rename to with_opp? <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
merge_screw_lr = False
merge_screw_abc = False

fuse_slots = None
#fuse_slots = [[210, 310], [240, 340], [250, 350]]
#fuse_slots = [[210, 310], [230, 330], [235, 335]]
#fuse_slots = [[210, 310], [220, 320], [225, 325]]

# %%
do_it(subjects=subjects, sensors_list=sensors_list,
      fuse_slots=fuse_slots,
      merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc, 
      show_time=True, show_dots=True, debug=True, deep_debug=False)
# Out:
# got name None
# subjects = all10
# name = plots/all10_fusion_identity_diff_int1_min_max_mean_noops_20190509-090210
# make and fill dataloader with all paths
# fill with MM, mmt0p, mmt0c, mmt1p, mmt1c, mmt2p, mmt2c, mmt3p, mmt3c, mmt4p, mmt4c, mmt5p, mmt5c, mmt6p, mmt6c, mmt7p, mmt7c, mmt8p, mmt8c, mmt9p, mmt9c, JP01, JP02, JP03, JP10, JPt1, JPt2, JPt3, JPt4, JP05, JPall, JP20, AR, CA, MJ, JH05, JH10, CD, Nomist,
# subjects = all10
# subjects = ['JP10', 'MM', 'AR', 'MJ', 'CD', 'JH10']
# getting data of subjects ['JP10', 'MM', 'AR', 'MJ', 'CD', 'JH10']
# give all rec_paths? - False
# subject_list = ['JP10', 'MM', 'AR', 'MJ', 'CD', 'JH10']
# giving out subject_tup MM
# giving out subject_tup JP10
# giving out subject_tup AR
# giving out subject_tup MJ
# giving out subject_tup JH10
# giving out subject_tup CD
# Start time = 2019-05-09 09:02:10.397955
# took default sensors_list
# -getting data for 60 paths
# ............................................................ done, 0:00:50.304430
# -deleting counter  done, 0:00:00.674147
# -concat data      done, 0:00:00.020979
# -concat targets    done, 0:00:00.045843
#
# data prep duration = 0:00:51.045399
#
# sessions = list of all sessions, 1 session = list of all slots, 1 slot = dataframe with data between timestamp borders
# all_targets = list of all targets (from all sessions), 1 targets_list = dataframe with targets = ground truths = Y
# concat_data = sessions concatinated into one list, where 1 slot = 1 element in list (np array aus dataframe -> flatten
# concat_targets = tba
#
# worked with 60 paths:
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...
# Analysed sensors: , dist, pos, acc, gyro
# Differential features: , identity, diff, int1 - Statistical features: , min, max, mean
# Number of Sessions = 60
# Subjects = , JP10, MM, AR, MJ, CD, JH10
# Accuracy = 93.46092503987241
# Mode =  no_opp
# ---train_subjects = None
# preparation duration = 0:00:58.241179
# prediciton duration  = 0:03:44.589949
# drawing duration     = 0:00:03.947437

# %% [raw]
# subjects = 'MM'
#
# do_it(subjects=subjects, sensors_list=sensors_list,
#       fuse_slots=fuse_slots,
#       merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc,
#       show_time=False, show_dots=False, debug=False, deep_debug=False)

# %% [raw]
# subjects = 'AR'
#
# do_it(subjects=subjects, sensors_list=sensors_list,
#       fuse_slots=fuse_slots,
#       merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc,
#       show_time=False, show_dots=False, debug=False, deep_debug=False)

# %% [raw]
# subjects = 'JH05'
#
# do_it(subjects=subjects, sensors_list=sensors_list,
#       fuse_slots=fuse_slots,
#       merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc,
#       show_time=False, show_dots=False, debug=False, deep_debug=False)

# %% [raw]
# subjects = 'MJ'
#
# do_it(subjects=subjects, sensors_list=sensors_list,
#       fuse_slots=fuse_slots,
#       merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc,
#       show_time=False, show_dots=False, debug=False, deep_debug=False)

# %% [raw]
# subjects = 'CD'
#
# do_it(subjects=subjects, sensors_list=sensors_list,
#       fuse_slots=fuse_slots,
#       merge_opposites=merge_opposites, merge_screw_lr=merge_screw_lr, merge_screw_abc=merge_screw_abc,
#       show_time=False, show_dots=False, debug=False, deep_debug=False)
